# %%
import matplotlib.pyplot as plt

plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %% [markdown]
# ## 주사위 시뮬레이션
# 1. 주사위를 굴린다.
# 2. 나온 결과를 기록한다.
# 3. 1~2 과정을 n번 반복한다.
# 4. 주사위의 눈이 나온 횟수를 히스토그램으로 그린다.

# %%
import random
print(random.randint(1,6))
# Out:
# 6

# %%
import random
dice = []

for i in range(5):
    dice.append(random.randint(1,6))



print(dice)
# Out:
# [6, 1, 6, 2, 2]
# [5, 2, 4, 6, 1]
# [2, 1, 4, 1, 4]
# [6, 2, 4, 2, 3]
# [3, 2, 4, 4, 5]
# [5, 6, 3, 3, 2]
# [4, 4, 3, 5, 2]
# [3, 2, 4, 5, 3]

# %%
'''import random
dice = []

while True:

    for i in range(2):
        dice.append(random.randint(1,6))

    if sum(dice) == 2:

        break

print(dice)'''
# Out:
# 'import random\ndice = []\n\nwhile True:\n\n    for i in range(2):\n        dice.append(random.randint(1,6))\n\n    if sum(dice) == 2:\n\n        break\n\nprint(dice)'

# %% [markdown]
# ## 서울의 최고기온을 히스토그램으로 표현하기

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))

plt.hist(result, bins=100, color='r')
# Out:
# (array([1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 2.000e+00,
#         4.000e+00, 5.000e+00, 9.000e+00, 1.100e+01, 2.300e+01, 1.500e+01,
#         3.900e+01, 3.700e+01, 5.000e+01, 5.000e+01, 7.500e+01, 7.200e+01,
#         1.100e+02, 1.180e+02, 1.730e+02, 1.520e+02, 2.240e+02, 2.240e+02,
#         2.270e+02, 3.010e+02, 2.540e+02, 3.820e+02, 4.230e+02, 3.990e+02,
#         4.740e+02, 4.450e+02, 5.290e+02, 5.120e+02, 5.270e+02, 5.870e+02,
#         5.320e+02, 6.140e+02, 6.390e+02, 4.860e+02, 6.300e+02, 4.870e+02,
#         5.560e+02, 4.950e+02, 5.660e+02, 5.150e+02, 4.160e+02, 5.170e+02,
#         3.990e+02, 5.050e+02, 5.290e+02, 4.130e+02, 4.680e+02, 4.360e+02,
#         4.850e+02, 5.050e+02, 4.320e+02, 4.760e+02, 4.210e+02, 5.560e+02,
#         4.660e+02, 5.520e+02, 5.380e+02, 4.680e+02, 6.560e+02, 5.580e+02,
#         6.830e+02, 7.300e+02, 6.310e+02, 7.770e+02, 5.990e+02, 8.230e+02,
#         8.520e+02, 8.030e+02, 9.790e+02, 7.780e+02, 1.032e+03, 1.015e+03,
#         8.060e+02, 1.004e+03, 7.050e+02, 9.460e+02, 7.120e+02, 7.310e+02,
#         6.550e+02, 4.940e+02, 5.100e+02, 3.560e+02, 3.190e+02, 2.440e+02,
#         1.550e+02, 1.250e+02, 8.500e+01, 6.500e+01, 3.200e+01, 2.100e+01,
#         1.400e+01, 7.000e+00, 0.000e+00, 1.000e+00]),
#  array([-16.3  , -15.741, -15.182, -14.623, -14.064, -13.505, -12.946,
#         -12.387, -11.828, -11.269, -10.71 , -10.151,  -9.592,  -9.033,
#          -8.474,  -7.915,  -7.356,  -6.797,  -6.238,  -5.679,  -5.12 ,
#          -4.561,  -4.002,  -3.443,  -2.884,  -2.325,  -1.766,  -1.207,
#          -0.648,  -0.089,   0.47 ,   1.029,   1.588,   2.147,   2.706,
#           3.265,   3.824,   4.383,   4.942,   5.501,   6.06 ,   6.619,
#           7.178,   7.737,   8.296,   8.855,   9.414,   9.973,  10.532,
#          11.091,  11.65 ,  12.209,  12.768,  13.327,  13.886,  14.445,
#          15.004,  15.563,  16.122,  16.681,  17.24 ,  17.799,  18.358,
#          18.917,  19.476,  20.035,  20.594,  21.153,  21.712,  22.271,
#          22.83 ,  23.389,  23.948,  24.507,  25.066,  25.625,  26.184,
#          26.743,  27.302,  27.861,  28.42 ,  28.979,  29.538,  30.097,
#          30.656,  31.215,  31.774,  32.333,  32.892,  33.451,  34.01 ,
#          34.569,  35.128,  35.687,  36.246,  36.805,  37.364,  37.923,
#          38.482,  39.041,  39.6  ]),
#  <BarContainer object of 100 artists>)

# %%
import random
import matplotlib.pyplot as plt
dice = []

for i in range(5):
    dice.append(random.randint(1,6))
print(dice)
plt.hist(dice)
plt.show()
# Out:
# [5, 6, 1, 3, 3]

# %%
import random
import matplotlib.pyplot as plt
dice = []

for i in range(500000):
    dice.append(random.randint(1,6))
print(dice)
plt.hist(dice)
plt.show()
# Out:
# [4, 2, 5, 4, 4, 3, 6, 1, 6, 6, 3, 5, 3, 1, 1, 2, 2, 1, 2, 2, 4, 2, 4, 6, 5, 1, 2, 5, 5, 3, 3, 1, 4, 5, 2, 5, 1, 4, 2, 4, 5, 3, 1, 1, 3, 3, 4, 1, 3, 5, 1, 4, 2, 2, 2, 4, 4, 2, 3, 2, 6, 4, 5, 1, 6, 5, 4, 2, 5, 1, 2, 5, 3, 1, 1, 3, 6, 5, 6, 5, 1, 6, 6, 6, 2, 2, 2, 2, 2, 1, 6, 2, 2, 4, 5, 1, 4, 3, 1, 3, 1, 6, 3, 2, 6, 1, 5, 2, 3, 5, 3, 1, 4, 5, 2, 4, 4, 3, 3, 2, 5, 5, 5, 2, 4, 4, 3, 6, 6, 4, 3, 5, 4, 2, 6, 2, 2, 3, 6, 3, 4, 6, 4, 3, 2, 1, 3, 5, 1, 3, 5, 4, 5, 1, 5, 5, 2, 5, 4, 1, 1, 2, 2, 3, 3, 4, 1, 6, 5, 2, 6, 2, 3, 4, 3, 6, 6, 6, 4, 6, 2, 4, 4, 6, 6, 5, 2, 6, 6, 2, 2, 4, 1, 6, 3, 6, 4, 2, 1, 1, 4, 1, 3, 5, 4, 3, 3, 3, 5, 1, 5, 4, 2, 4, 4, 6, 4, 6, 2, 6, 5, 4, 3, 2, 1, 1, 1, 2, 5, 1,
 2, 3, 4, 5, 4, 3, 5, 1, 6, 1, 3, 4, 2, 1, 3, 1, 6, 2, 5, 5, 2, 5, 5, 3, 3, 2, 3, 3, 1, 6, 4, 4, 6, 6, 2, 1, 6, 2, 1, 2, 5, 6, 5, 6, 5, 6, 3, 4, 4, 4, 3, 3, 3, 2, 4, 3, 5, 5, 4, 2, 3, 5, 1, 3, 5, 3, 6, 3, 4, 3, 5, 2, 2, 5, 2, 6, 4, 5, 4, 4, 3, 1, 3, 4, 5, 6, 4, 2, 6, 1, 6, 1, 5, 6, 5, 5, 3, 2, 3, 2, 2, 6, 3, 3, 6, 2, 1, 6, 3, 4, 5, 5, 5, 2, 6, 2, 3, 6, 1,  ...

# %%
import csv
import matplotlib.pyplot as plt

f=open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            result.append(float(row[-1]))


plt.hist(result, bins=100, color='red')
# Out:
# (array([  1.,   0.,   1.,   0.,   0.,   0.,   2.,   0.,   2.,   1.,   1.,
#           3.,   4.,   1.,   6.,   2.,   5.,   6.,   6.,   6.,  16.,   6.,
#          10.,  15.,  13.,  21.,  16.,   9.,  21.,  30.,  21.,  29.,  32.,
#          28.,  30.,  41.,  42.,  37.,  47.,  39.,  60.,  54.,  56.,  61.,
#          41.,  72.,  70.,  60.,  60.,  82., 117.,  79.,  87.,  71.,  96.,
#          91.,  90., 101.,  73., 141.,  66.,  89.,  97.,  72.,  84.,  66.,
#          76.,  62.,  64.,  63.,  76.,  50.,  37.,  34.,  42.,  34.,  23.,
#          21.,  27.,  37.,  21.,  12.,  24.,   9.,   4.,   8.,   9.,   7.,
#           5.,   6.,   4.,   3.,   1.,   2.,   0.,   0.,   0.,   0.,   0.,
#           1.]),
#  array([18.6 , 18.81, 19.02, 19.23, 19.44, 19.65, 19.86, 20.07, 20.28,
#         20.49, 20.7 , 20.91, 21.12, 21.33, 21.54, 21.75, 21.96, 22.17,
#         22.38, 22.59, 22.8 , 23.01, 23.22, 23.43, 23.64, 23.85, 24.06,
#         24.27, 24.48, 24.69, 24.9 , 25.11, 25.32, 25.53, 25.74, 25.95,
#         26.16, 26.37, 26.58, 26.79, 27.  , 27.21, 27.42, 27.63, 27.84,
#         28.05, 28.26, 28.47, 28.68, 28.89, 29.1 , 29.31, 29.52, 29.73,
#         29.94, 30.15, 30.36, 30.57, 30.78, 30.99, 31.2 , 31.41, 31.62,
#         31.83, 32.04, 32.25, 32.46, 32.67, 32.88, 33.09, 33.3 , 33.51,
#         33.72, 33.93, 34.14, 34.35, 34.56, 34.77, 34.98, 35.19, 35.4 ,
#         35.61, 35.82, 36.03, 36.24, 36.45, 36.66, 36.87, 37.08, 37.29,
#         37.5 , 37.71, 37.92, 38.13, 38.34, 38.55, 38.76, 38.97, 39.18,
#         39.39, 39.6 ]),
#  <BarContainer object of 100 artists>)
